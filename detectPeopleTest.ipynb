# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonellaRincones/DataSciencePractice/blob/main/detectPeopleTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import imutils
import numpy as np
import argparse
import io
import PIL
from google.colab.patches import cv2_imshow

# %%
HOGCV = cv2.HOGDescriptor()
HOGCV.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# %%
def detect(frame):
    bounding_box_cordinates, weights =  HOGCV.detectMultiScale(frame, winStride = (4, 4), padding = (8, 8), scale = 1.03)
    
    person = 1
    for x,y,w,h in bounding_box_cordinates:
        cv2.rectangle(frame, (x,y), (x+w,y+h), (0,255,0), 2)
        cv2.putText(frame, f'person {person}', (x,y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 1)
        person += 1
    
    cv2.putText(frame, 'Status : Detecting ', (40,40), cv2.FONT_HERSHEY_DUPLEX, 0.8, (255,0,0), 2)
    cv2.putText(frame, f'Total Persons : {person-1}', (40,70), cv2.FONT_HERSHEY_DUPLEX, 0.8, (255,0,0), 2)
    cv2_imshow(frame)
    return frame

# %%
from google.colab import files 
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9070a833-4a26-4adf-9f3e-07fa4267194e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9070a833-4a26-4adf-9f3e-07fa4267194e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pedestrians-walk-street-stock-today-main-180911-1366982.jpg to pedestrians-walk-street-stock-today-main-180911-1366982 (1).jpg

# %%
im =

# %%
def detectByPathImage():
    #im = PIL.Image.open(io.BytesIO(uploaded['pedestrians-walk-street-stock-today-main-180911-1366982.jpg']))
    image = cv2.imread('pedestrians-walk-street-stock-today-main-180911-1366982.jpg')
    image = imutils.resize(image, width = min(800, image.shape[1])) 
    result_image = detect(image)
    cv2_imshow(result_image);
    cv2.waitKey(0)

# %%
imag = cv2.imread('pedestrians-walk-street-stock-today-main-180911-1366982.jpg')

# %%
detectByPathImage()
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7F643CD9E8D0>
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7F643CDC8590>
